# %% [markdown]
# # Class 1 - Introduction to Data in Python

# %% [markdown]
# ## Intro to Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Creating a DataFrame

# %%
students = {
    'FIRST_NAME': ['Daniel', 'Ben', 'Kavita', 'Linda', 
                    'Omar','Jane', 'Felicia', 'Rachel', 
                    'Bob'],
    'LAST_NAME': ['Smith', 'Leibstrom', 'Kanabar', 'Thiel',
                  'Reichel', 'OConner', 'Rao', 'Crock', 
                  'McDonald'],
    'YEAR': [1, 1, 1, 4, 2, 2, 3, 1, 1],
    'HOME_STATE': ['NY', 'NY', 'PA', 'CA', 'OK', 'HI', 
                   'NY','FL', 'FL'],
    'AGE': [18, 19, 19, 22, 21, 19, 20, 17, 18],
    'CALC_101_FINAL': [90, 80, None, 60, 70, None,None, 
                       None, 98],
    'ENGLISH_101_FINAL': [80, None, None, 40, 50, None,
                          None, 60, 65]}

df_students = pd.DataFrame(students)

# %%
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %% [markdown]
# ### Accessing columns in DataFrames

# %%
df_students['FIRST_NAME']
# Out:
# 0     Daniel
# 1        Ben
# 2     Kavita
# 3      Linda
# 4       Omar
# 5       Jane
# 6    Felicia
# 7     Rachel
# 8        Bob
# Name: FIRST_NAME, dtype: object

# %%
df_students.FIRST_NAME
# Out:
# 0     Daniel
# 1        Ben
# 2     Kavita
# 3      Linda
# 4       Omar
# 5       Jane
# 6    Felicia
# 7     Rachel
# 8        Bob
# Name: FIRST_NAME, dtype: object

# %%
i = 'HOME_STATE'
df_students[i]
# Out:
# 0    NY
# 1    NY
# 2    PA
# 3    CA
# 4    OK
# 5    HI
# 6    NY
# 7    FL
# 8    FL
# Name: HOME_STATE, dtype: object

# %%
df_students[['FIRST_NAME']]
# Out:
#   FIRST_NAME
# 0     Daniel
# 1        Ben
# 2     Kavita
# 3      Linda
# 4       Omar
# 5       Jane
# 6    Felicia
# 7     Rachel
# 8        Bob

# %%
df_students[['FIRST_NAME', 'LAST_NAME']]
# Out:
#   FIRST_NAME  LAST_NAME
# 0     Daniel      Smith
# 1        Ben  Leibstrom
# 2     Kavita    Kanabar
# 3      Linda      Thiel
# 4       Omar    Reichel
# 5       Jane    OConner
# 6    Felicia        Rao
# 7     Rachel      Crock
# 8        Bob   McDonald

# %%
# df_students['FIRST_NAME', 'LAST_NAME']

# %% [markdown]
# ### Changing column names and row indexes

# %%
df_students.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'YEAR', 'HOME_STATE', 'AGE',
#        'CALC_101_FINAL', 'ENGLISH_101_FINAL'],
#       dtype='object')

# %%
df_students.columns = ['FIRST_NAME', 
                       'LAST_NAME', 
                       'YEAR', 
                       'HOME_STATE', 
                       'AGE', 
                       'CALC_101_FINAL', 
                       'ENGLISH_101_FINAL_SCORE']

# %%
df_students.index = [1,2,3,4,5,6,7,8,9]

# %%
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 1     Daniel      Smith     1         NY   18            90.0
# 2        Ben  Leibstrom     1         NY   19            80.0
# 3     Kavita    Kanabar     1         PA   19             NaN
# 4      Linda      Thiel     4         CA   22            60.0
# 5       Omar    Reichel     2         OK   21            70.0
# 6       Jane    OConner     2         HI   19             NaN
# 7    Felicia        Rao     3         NY   20             NaN
# 8     Rachel      Crock     1         FL   17             NaN
# 9        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL_SCORE
# 1                     80.0
# 2                      NaN
# 3                      NaN
# 4                     40.0
# 5                     50.0
# 6                      NaN
# 7                      NaN
# 8                     60.0
# 9                     65.0

# %%
df_students.rename(columns={'ENGLISH_101_FINAL_SCORE':'ENGLISH_101_FINAL'})
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 1     Daniel      Smith     1         NY   18            90.0
# 2        Ben  Leibstrom     1         NY   19            80.0
# 3     Kavita    Kanabar     1         PA   19             NaN
# 4      Linda      Thiel     4         CA   22            60.0
# 5       Omar    Reichel     2         OK   21            70.0
# 6       Jane    OConner     2         HI   19             NaN
# 7    Felicia        Rao     3         NY   20             NaN
# 8     Rachel      Crock     1         FL   17             NaN
# 9        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 1               80.0
# 2                NaN
# 3                NaN
# 4               40.0
# 5               50.0
# 6                NaN
# 7                NaN
# 8               60.0
# 9               65.0

# %%
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 1     Daniel      Smith     1         NY   18            90.0
# 2        Ben  Leibstrom     1         NY   19            80.0
# 3     Kavita    Kanabar     1         PA   19             NaN
# 4      Linda      Thiel     4         CA   22            60.0
# 5       Omar    Reichel     2         OK   21            70.0
# 6       Jane    OConner     2         HI   19             NaN
# 7    Felicia        Rao     3         NY   20             NaN
# 8     Rachel      Crock     1         FL   17             NaN
# 9        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL_SCORE
# 1                     80.0
# 2                      NaN
# 3                      NaN
# 4                     40.0
# 5                     50.0
# 6                      NaN
# 7                      NaN
# 8                     60.0
# 9                     65.0

# %%
df_students = df_students.rename(
    columns={'ENGLISH_101_FINAL_SCORE':'ENGLISH_101_FINAL'})

# %%
df_students = df_students.reset_index(drop=True)

# %%
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %% [markdown]
# ### .head() and .shape

# %%
df_students.head()
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0

# %%
df_students.tail()
# Out:
#   FIRST_NAME LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 4       Omar   Reichel     2         OK   21            70.0
# 5       Jane   OConner     2         HI   19             NaN
# 6    Felicia       Rao     3         NY   20             NaN
# 7     Rachel     Crock     1         FL   17             NaN
# 8        Bob  McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %%
df_students.shape
# Out:
# (9, 7)

# %%
df_students.shape[0]
# Out:
# 9

# %%
len(df_students)
# Out:
# 9

# %%
# df_students.FIRST_NAME()

# %%
# df_students.shape()

# %%
df_students.reset_index
# Out:
# <bound method DataFrame.reset_index of   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0  >

# %% [markdown]
# ### Code Completion

# %% [markdown]
# Start typing `df_s` and hit tab to autocomplete.

# %%
# df_s + <Tab>
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %%
df_surfboard = 1

# %%
df_surfboard
# Out:
# 1

# %%
# df_students.E + <Tab>
df_students.ENGLISH_101_FINAL
# Out:
# 0    80.0
# 1     NaN
# 2     NaN
# 3    40.0
# 4    50.0
# 5     NaN
# 6     NaN
# 7    60.0
# 8    65.0
# Name: ENGLISH_101_FINAL, dtype: float64

# %%
# df_students.rename + <Shift> + <Tab> + <Tab>
# df_students.rename

# %% [markdown]
# ## Reading and writing data

# %% [markdown]
# ### Reading data

# %%
# %ls
# Out:
# Class 1.1 - Introduction to Data in Python.ipynb
# Class 1.2 - Exploring, Plotting, and Modifying Data in Python.ipynb
# My test notebook.ipynb
# items.csv
# orders.csv
# restaurants.csv
# students.csv
# summarized_orders.csv

# %%
# %ls 'data'
# Out:
# Items.csv             Students.xlsx         university.xlsx
# Restaurants.csv       Summarized orders.csv weather.csv
# Simplified orders.zip students.py

# %%
df_students = pd.read_excel('data/Students.xlsx', 
                            sheet_name='Sheet1')

# %%
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %%
df_summarized_orders = pd.read_csv('data/Summarized orders.csv')

# %%
df_summarized_orders.head()
# Out:
#       location         day  number of orders  percentage of deliveries
# 0  Bryant Park  2018-01-01               373                       0.0
# 1  Bryant Park  2018-01-02               789                       0.0
# 2  Bryant Park  2018-01-03               818                       0.0
# 3  Bryant Park  2018-01-04               782                       0.0
# 4  Bryant Park  2018-01-05               719                       0.0

# %%
df_summarized_orders.columns = ['RESTAURANT_NAME', 
                                'DATE', 
                                'NUM_ORDERS', 
                                'PERC_DELIVERY']

# %%
df_items = pd.read_csv('data/items.csv')

# %%
df_restaurants = pd.read_csv('data/restaurants.csv')

# %%
df_orders = pd.read_csv('data/Simplified orders.zip')

# %%
df_orders.shape
# Out:
# (2387224, 10)

# %% [markdown]
# ### Writing Data

# %%
df_students.to_csv('data/students.csv', index=False)

# %%
pd.read_csv('data/students.csv')
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %% [markdown]
# ## Column Types

# %%
df_orders.head()
# Out:
#    ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES  \
# 0  O1820060  2018-10-11 17:25:50        R10002  IN_STORE     1.0      2.0
# 1  O1011112  2018-05-31 11:35:00        R10003  IN_STORE     0.0      0.0
# 2   O752854  2018-04-21 18:12:57        R10001  DELIVERY     0.0      2.0
# 3  O2076864  2018-11-17 12:50:52        R10005    PICKUP     1.0      0.0
# 4  O1988898  2018-11-04 18:37:24        R10008  IN_STORE     0.0      0.0
#
#   MAIN BASE SIDE_1 SIDE_2
# 0  NaN  NaN    NaN    NaN
# 1  NaN  NaN    NaN    NaN
# 2   I0   I7    I15    I14
# 3   I0   I5     I9    I12
# 4   I1   I7     I9     I9

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387224 entries, 0 to 2387223
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ORDER_ID       object
#  1   DATETIME       object
#  2   RESTAURANT_ID  object
#  3   TYPE           object
#  4   DRINKS         float64
#  5   COOKIES        float64
#  6   MAIN           object
#  7   BASE           object
#  8   SIDE_1         object
#  9   SIDE_2         object
# dtypes: float64(2), object(8)
# memory usage: 182.1+ MB

# %%
df_orders.DATETIME = pd.to_datetime(df_orders.DATETIME)

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387224 entries, 0 to 2387223
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ORDER_ID       object
#  1   DATETIME       datetime64[ns]
#  2   RESTAURANT_ID  object
#  3   TYPE           object
#  4   DRINKS         float64
#  5   COOKIES        float64
#  6   MAIN           object
#  7   BASE           object
#  8   SIDE_1         object
#  9   SIDE_2         object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 182.1+ MB

# %%
df_orders.DATETIME.dt.day_name()
# Out:
# 0          Thursday
# 1          Thursday
# 2          Saturday
# 3          Saturday
# 4            Sunday
#              ...
# 2387219      Sunday
# 2387220    Saturday
# 2387221      Monday
# 2387222      Monday
# 2387223      Monday
# Name: DATETIME, Length: 2387224, dtype: object

# %%
df_summarized_orders.head()
# Out:
#   RESTAURANT_NAME        DATE  NUM_ORDERS  PERC_DELIVERY
# 0     Bryant Park  2018-01-01         373            0.0
# 1     Bryant Park  2018-01-02         789            0.0
# 2     Bryant Park  2018-01-03         818            0.0
# 3     Bryant Park  2018-01-04         782            0.0
# 4     Bryant Park  2018-01-05         719            0.0

# %%
df_summarized_orders.DATE = pd.to_datetime(df_summarized_orders.DATE)

# %%
df_summarized_orders.head()
# Out:
#   RESTAURANT_NAME       DATE  NUM_ORDERS  PERC_DELIVERY
# 0     Bryant Park 2018-01-01         373            0.0
# 1     Bryant Park 2018-01-02         789            0.0
# 2     Bryant Park 2018-01-03         818            0.0
# 3     Bryant Park 2018-01-04         782            0.0
# 4     Bryant Park 2018-01-05         719            0.0

# %% [markdown]
# ## Wrapping Up

# %%
df_students.to_csv('data/students.csv', index=False)
df_orders.to_csv('data/orders.csv', index=False)
df_summarized_orders.to_csv('data/summarized_orders.csv', index=False)
df_items.to_csv('data/items.csv', index=False)
df_restaurants.to_csv('data/restaurants.csv', index=False)
