# %% [markdown]
# # 1. Introduction to Data in Python

# %% [markdown]
# ## Intro to Pandas

# %%
import pandas as pd

# %%
df_orders = pd.read_csv('data/simplified_orders.zip')

# %%
df_orders.head()
# Out:
#    ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES  \
# 0  O1820060  2018-10-11 17:25:50        R10002  IN_STORE     1.0      2.0
# 1  O1011112  2018-05-31 11:35:00        R10003  IN_STORE     0.0      0.0
# 2   O752854  2018-04-21 18:12:57        R10001  DELIVERY     0.0      2.0
# 3  O2076864  2018-11-17 12:50:52        R10005    PICKUP     1.0      0.0
# 4  O1988898  2018-11-04 18:37:24        R10008  IN_STORE     0.0      0.0
#
#   MAIN BASE SIDE_1 SIDE_2
# 0  NaN  NaN    NaN    NaN
# 1  NaN  NaN    NaN    NaN
# 2   I0   I7    I15    I14
# 3   I0   I5     I9    I12
# 4   I1   I7     I9     I9

# %%
df_orders.describe().round(2)
# Out:
#            DRINKS     COOKIES
# count  2387224.00  2387224.00
# mean         0.10        0.26
# std          0.38        0.56
# min          0.00        0.00
# 25%          0.00        0.00
# 50%          0.00        0.00
# 75%          0.00        0.00
# max         25.00        2.00

# %%
df_orders.TYPE.value_counts(normalize=True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Creating DataFrames from scratch

# %%
students = {
    'FIRST_NAME': ['Daniel', 'Ben', 'Kavita', 'Linda', 
                    'Omar','Jane', 'Felicia', 'Rachel', 
                    'Bob'],
    'LAST_NAME': ['Smith', 'Leibstrom', 'Kanabar', 'Thiel',
                  'Reichel', 'OConner', 'Rao', 'Crock', 
                  'McDonald'],
    'YEAR': [1, 1, 1, 4, 2, 2, 3, 1, 1],
    'HOME_STATE': ['NY', 'NY', 'PA', 'CA', 'OK', 'HI', 
                   'NY','FL', 'FL'],
    'AGE': [18, 19, 19, 22, 21, 19, 20, 17, 18],
    'CALC_101_FINAL': [90, 80, None, 60, 70, None,None, 
                       None, 98],
    'ENGLISH_101_FINAL': [80, None, None, 40, 50, None,
                          None, 60, 65]}

# %%
df_students = pd.DataFrame(students)

# %%
df_students
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %% [markdown]
# ## Learning about a DataFrame

# %%
df_students.head()
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0

# %%
df_students.head(3)
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN

# %%
df_students.tail()
# Out:
#   FIRST_NAME LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 4       Omar   Reichel     2         OK   21            70.0
# 5       Jane   OConner     2         HI   19             NaN
# 6    Felicia       Rao     3         NY   20             NaN
# 7     Rachel     Crock     1         FL   17             NaN
# 8        Bob  McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %%
df_students.shape
# Out:
# (9, 7)

# %%
len(df_students)
# Out:
# 9

# %%
df_students.describe().round(1)
# Out:
#        YEAR   AGE  CALC_101_FINAL  ENGLISH_101_FINAL
# count   9.0   9.0             5.0                5.0
# mean    1.8  19.2            79.6               59.0
# std     1.1   1.6            15.2               15.2
# min     1.0  17.0            60.0               40.0
# 25%     1.0  18.0            70.0               50.0
# 50%     1.0  19.0            80.0               60.0
# 75%     2.0  20.0            90.0               65.0
# max     4.0  22.0            98.0               80.0

# %%
df_students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FIRST_NAME         9 non-null      object
#  1   LAST_NAME          9 non-null      object
#  2   YEAR               9 non-null      int64
#  3   HOME_STATE         9 non-null      object
#  4   AGE                9 non-null      int64
#  5   CALC_101_FINAL     5 non-null      float64
#  6   ENGLISH_101_FINAL  5 non-null      float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 632.0+ bytes

# %% [markdown]
# ## Accessing columns

# %%
df_students.FIRST_NAME
# Out:
# 0     Daniel
# 1        Ben
# 2     Kavita
# 3      Linda
# 4       Omar
# 5       Jane
# 6    Felicia
# 7     Rachel
# 8        Bob
# Name: FIRST_NAME, dtype: object

# %%
df_students['FIRST_NAME']
# Out:
# 0     Daniel
# 1        Ben
# 2     Kavita
# 3      Linda
# 4       Omar
# 5       Jane
# 6    Felicia
# 7     Rachel
# 8        Bob
# Name: FIRST_NAME, dtype: object

# %%
df_students[['FIRST_NAME', 'LAST_NAME']]
# Out:
#   FIRST_NAME  LAST_NAME
# 0     Daniel      Smith
# 1        Ben  Leibstrom
# 2     Kavita    Kanabar
# 3      Linda      Thiel
# 4       Omar    Reichel
# 5       Jane    OConner
# 6    Felicia        Rao
# 7     Rachel      Crock
# 8        Bob   McDonald

# %% [markdown]
# ## Sorting Data

# %%
df_students.sort_values('HOME_STATE')
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 3      Linda      Thiel     4         CA   22            60.0
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
# 5       Jane    OConner     2         HI   19             NaN
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 6    Felicia        Rao     3         NY   20             NaN
# 4       Omar    Reichel     2         OK   21            70.0
# 2     Kavita    Kanabar     1         PA   19             NaN
#
#    ENGLISH_101_FINAL
# 3               40.0
# 7               60.0
# 8               65.0
# 5                NaN
# 0               80.0
# 1                NaN
# 6                NaN
# 4               50.0
# 2                NaN

# %%
# Sorting challenge
df_students.sort_values('LAST_NAME', ascending=False)
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 3      Linda      Thiel     4         CA   22            60.0
# 0     Daniel      Smith     1         NY   18            90.0
# 4       Omar    Reichel     2         OK   21            70.0
# 6    Felicia        Rao     3         NY   20             NaN
# 5       Jane    OConner     2         HI   19             NaN
# 8        Bob   McDonald     1         FL   18            98.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 7     Rachel      Crock     1         FL   17             NaN
#
#    ENGLISH_101_FINAL
# 3               40.0
# 0               80.0
# 4               50.0
# 6                NaN
# 5                NaN
# 8               65.0
# 1                NaN
# 2                NaN
# 7               60.0

# %%
df_students.sort_values(['HOME_STATE', 'LAST_NAME'])
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 3      Linda      Thiel     4         CA   22            60.0
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
# 5       Jane    OConner     2         HI   19             NaN
# 1        Ben  Leibstrom     1         NY   19            80.0
# 6    Felicia        Rao     3         NY   20             NaN
# 0     Daniel      Smith     1         NY   18            90.0
# 4       Omar    Reichel     2         OK   21            70.0
# 2     Kavita    Kanabar     1         PA   19             NaN
#
#    ENGLISH_101_FINAL
# 3               40.0
# 7               60.0
# 8               65.0
# 5                NaN
# 1                NaN
# 6                NaN
# 0               80.0
# 4               50.0
# 2                NaN

# %%
df_students.CALC_101_FINAL.sort_values()
# Out:
# 3    60.0
# 4    70.0
# 1    80.0
# 0    90.0
# 8    98.0
# 2     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# Name: CALC_101_FINAL, dtype: float64

# %%
df_students.sort_index()
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0

# %%
# Thirstiest order challenge
df_orders.sort_values('DRINKS', ascending=False).head(10)
# Out:
#          ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  \
# 779203   O1405572  2018-08-06 15:58:16        R10005  IN_STORE    25.0
# 551919   O1156159  2018-06-23 12:52:15        R10007  IN_STORE    25.0
# 952895   O1729582  2018-09-27 20:55:05        R10002    PICKUP    25.0
# 779826   O1938281  2018-10-28 17:50:01        R10006  DELIVERY    25.0
# 1975167   O854955  2018-05-07 13:02:29        R10002  IN_STORE    25.0
# 603981   O1194251  2018-06-29 14:09:59        R10004  IN_STORE    25.0
# 1902953  O1911299  2018-10-24 18:09:22        R10008  IN_STORE    24.0
# 1627821  O1806191  2018-10-09 18:38:54        R10004    PICKUP    24.0
# 674206   O1778228  2018-10-05 12:14:54        R10002  IN_STORE    24.0
# 1896598   O328863  2018-02-19 17:21:52        R10007  IN_STORE    24.0
#
#          COOKIES MAIN BASE SIDE_1 SIDE_2
# 779203       1.0   I3   I7    I14    I10
# 551919       1.0   I0   I5     I8     I8
# 952895       0.0   I1   I6    I11    I15
# ...

# %% [markdown]
# ## Plotting Data

# %%
df_students.CALC_101_FINAL.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_students.plot(x='LAST_NAME', y='CALC_101_FINAL', kind='bar')
# Out:
# <AxesSubplot:xlabel='LAST_NAME'>

# %% [markdown]
# ## Code completion

# %% [markdown]
# TAB to autocomplete variables, columns, and functions
#
# SHIFT + TAB + TAB to pull up documentation on any function

# %% [markdown]
# ## Reading and writing data

# %% [markdown]
# ### Reading data

# %%
df_summarized_orders = pd.read_csv('data/summarized_orders.csv')

# %%
df_summarized_orders.head()
# Out:
#       location         day  number of orders  percentage of deliveries
# 0  Bryant Park  2018-01-01               373                       0.0
# 1  Bryant Park  2018-01-02               789                       0.0
# 2  Bryant Park  2018-01-03               818                       0.0
# 3  Bryant Park  2018-01-04               782                       0.0
# 4  Bryant Park  2018-01-05               719                       0.0

# %%
df_orders = pd.read_csv('data/simplified_orders.zip')

# %%
df_orders.head()
# Out:
#    ORDER_ID             DATETIME RESTAURANT_ID      TYPE  DRINKS  COOKIES  \
# 0  O1820060  2018-10-11 17:25:50        R10002  IN_STORE     1.0      2.0
# 1  O1011112  2018-05-31 11:35:00        R10003  IN_STORE     0.0      0.0
# 2   O752854  2018-04-21 18:12:57        R10001  DELIVERY     0.0      2.0
# 3  O2076864  2018-11-17 12:50:52        R10005    PICKUP     1.0      0.0
# 4  O1988898  2018-11-04 18:37:24        R10008  IN_STORE     0.0      0.0
#
#   MAIN BASE SIDE_1 SIDE_2
# 0  NaN  NaN    NaN    NaN
# 1  NaN  NaN    NaN    NaN
# 2   I0   I7    I15    I14
# 3   I0   I5     I9    I12
# 4   I1   I7     I9     I9

# %%
df_university = pd.read_excel('data/university.xlsx')

# %%
# Read Excel sheet by name challenge
df_full_time = pd.read_excel('data/university.xlsx', 
                            sheet_name='full_time')

df_part_time = pd.read_excel('data/university.xlsx', 
                            sheet_name='part_time')

df_grades = pd.read_excel('data/university.xlsx', 
                            sheet_name='grades')

# %% [markdown]
# ### Writing Data

# %%
df_students.to_csv('data/students.csv', index=False)

# %%
pd.read_csv('data/students.csv')
# Out:
#   FIRST_NAME  LAST_NAME  YEAR HOME_STATE  AGE  CALC_101_FINAL  \
# 0     Daniel      Smith     1         NY   18            90.0
# 1        Ben  Leibstrom     1         NY   19            80.0
# 2     Kavita    Kanabar     1         PA   19             NaN
# 3      Linda      Thiel     4         CA   22            60.0
# 4       Omar    Reichel     2         OK   21            70.0
# 5       Jane    OConner     2         HI   19             NaN
# 6    Felicia        Rao     3         NY   20             NaN
# 7     Rachel      Crock     1         FL   17             NaN
# 8        Bob   McDonald     1         FL   18            98.0
#
#    ENGLISH_101_FINAL
# 0               80.0
# 1                NaN
# 2                NaN
# 3               40.0
# 4               50.0
# 5                NaN
# 6                NaN
# 7               60.0
# 8               65.0
